# %% [markdown]
# CI Bus Routing Experimentation - Learning Rate Experimentation
#
# Part 1: Set Up Codespace

# %%
import gymnasium as gym
import os
import torch
import torch.nn as nn
import numpy as np
from random import sample
from gymnasium import spaces
from collections import deque
from matplotlib import pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777121978.374536 1766860 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Check for GPU availability (CUDA first, then MPS, then CPU)
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu
# /home/users/jfr29/.local/lib/python3.11/site-packages/torch/cuda/__init__.py:180: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12080). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# Part 2: Custom Gymnasium Environment

# %%
class BusEnv(gym.Env):
    metadata = {"render_modes": ["human"], "render_fps": 4}

    def __init__(self, config=None, render_mode=None):
        super().__init__()

        config = config or {}

        # Route / simulation settings
        self.num_stops = config.get("num_stops", 14)
        self.max_buses = config.get("max_buses", 6)
        self.bus_capacity = config.get("bus_capacity", 100)
        self.episode_length = config.get("episode_length", 960)  # 8:00am to 12:00am, 1 step = 1 minute
        self.max_queue = config.get("max_queue", 500)

        self.base_arrival_rates = np.array(
            config.get(
                "base_arrival_rates",
                [30, 2, 2, 2, 2, 2, 2, 40, 4, 2, 2, 2, 2, 2],
            ),
            dtype=np.float32,
        )

        # Reward weights
        self.pickup_reward = config.get("pickup_reward", 0.1)
        self.left_behind_penalty = config.get("left_behind_penalty", 0.001)
        self.waiting_penalty = config.get("waiting_penalty", 0.00001)
        self.active_bus_penalty = config.get("active_bus_penalty", 0.1)

        self.render_mode = render_mode
        assert render_mode is None or render_mode in self.metadata["render_modes"]

        # Bus features per bus:
        # stop, occupancy, active, held, segment
        self.bus_features = 5

        # Observation:
        # [timestep, active_bus_count]
        # + queue lengths for each stop
        # + time since last service for each stop
        # + bus states for each possible bus
        obs_size = (
            2 + self.num_stops + self.num_stops + self.max_buses * self.bus_features
        )
        self.observation_space = spaces.Box(
            low=0.0,
            high=1000.0,
            shape=(obs_size,),
            dtype=np.float32,
        )

        # 0 = normal operation
        # 1 = add a bus
        # 2 = remove a bus
        # 3 = hold a bus
        self.action_space = spaces.Discrete(4)

        self.window = None
        self.clock = None

        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.timestep = 0

        # Queue at each stop
        self.queues = np.zeros(self.num_stops, dtype=np.int32)

        # How many steps since each stop was last served
        self.last_service = np.zeros(self.num_stops, dtype=np.int32)

        # Bus states
        self.buses = []
        for _ in range(self.max_buses):
            self.buses.append(
                {
                    "stop": 0,
                    "occupancy": 0,
                    "active": 0,
                    "held": 0,
                }
            )

        # Start with one active bus at stop 0
        self.buses[0]["active"] = 1
        self.buses[0]["stop"] = 0
        self.buses[0]["occupancy"] = 0
        self.buses[0]["held"] = 0

        obs = self._get_obs()
        info = self._get_info()

        return obs, info

    def step(self, action):
        self.timestep += 1

        self._generate_passengers()
        self._apply_action(action)
        picked_up, left_behind = self._move_buses_and_board()

        # Increase time since last service for all stops,
        # then reset happens inside boarding when a stop is served
        self.last_service += 1

        total_waiting = int(np.sum(self.queues))
        active_buses = self._active_bus_count()

        reward = (
            self.pickup_reward * picked_up
            - self.left_behind_penalty * left_behind
            - self.waiting_penalty * total_waiting
            - self.active_bus_penalty * active_buses
        )

        terminated = self.timestep >= self.episode_length
        truncated = False

        obs = self._get_obs()
        info = self._get_info()
        info.update(
            {
                "picked_up": picked_up,
                "left_behind": left_behind,
                "reward": reward,
            }
        )

        if self.render_mode == "human":
            self.render()

        return obs, reward, terminated, truncated, info

    def render(self):
        print(f"\nTime step: {self.timestep}")
        print(f"Queues: {self.queues.tolist()}")
        for i, bus in enumerate(self.buses):
            if bus["active"]:
                print(
                    f"Bus {i}: stop={bus['stop']}, "
                    f"segment={'WB' if self.is_westbound_stop(bus['stop']) else 'EB'}, "
                    f"occupancy={bus['occupancy']}, held={bus['held']}"
                )

    def close(self):
        pass

    def _get_obs(self):
        obs = [self.timestep, self._active_bus_count()]

        # stop queues
        obs.extend(self.queues.tolist())

        # time since last service
        obs.extend(self.last_service.tolist())

        # per-bus features
        for bus in self.buses:
            segment = 0 if self.is_westbound_stop(bus["stop"]) else 1
            obs.extend(
                [
                    bus["stop"],
                    bus["occupancy"],
                    bus["active"],
                    bus["held"],
                    segment,
                ]
            )

        return np.array(obs, dtype=np.float32)

    def _get_info(self):
        return {
            "timestep": self.timestep,
            "active_buses": self._active_bus_count(),
            "total_waiting": int(np.sum(self.queues)),
        }

    def _generate_passengers(self):
        arrivals = self.np_random.poisson(self.base_arrival_rates).astype(np.int32)

        # 9:00am class spike
        # If 8:00 = step 0, then 9:00 = step 60
        if 55 <= self.timestep <= 70:
            arrivals[0] += self.np_random.poisson(150)  # East campus terminal spike

        # 11:30am spike
        if 205 <= self.timestep <= 220:
            arrivals[7] += self.np_random.poisson(150)  # West campus terminal spike

        self.queues = np.minimum(self.queues + arrivals, self.max_queue)

    def _apply_action(self, action):
        if action == 1:
            self._add_bus()
        elif action == 2:
            self._remove_bus()
        elif action == 3:
            self._hold_bus()
        # action == 0 means normal operation

    def _add_bus(self):
        inactive_indices = [i for i, b in enumerate(self.buses) if b["active"] == 0]
        if not inactive_indices:
            return

        # Place new bus at busiest stop
        busiest_stop = int(np.argmax(self.queues))
        idx = inactive_indices[0]

        self.buses[idx]["active"] = 1
        self.buses[idx]["stop"] = busiest_stop
        self.buses[idx]["occupancy"] = 0
        self.buses[idx]["held"] = 0

    def _remove_bus(self):
        active_indices = [i for i, b in enumerate(self.buses) if b["active"] == 1]

        # Keep at least one bus active
        if len(active_indices) <= 1:
            return

        # Remove emptiest active bus
        remove_idx = min(active_indices, key=lambda i: self.buses[i]["occupancy"])

        self.buses[remove_idx]["active"] = 0
        self.buses[remove_idx]["occupancy"] = 0
        self.buses[remove_idx]["held"] = 0

    def _hold_bus(self):
        active_indices = [i for i, b in enumerate(self.buses) if b["active"] == 1]
        if not active_indices:
            return

        # Hold the bus closest to the busiest stop
        busiest_stop = int(np.argmax(self.queues))

        def loop_distance(a, b):
            forward = (b - a) % self.num_stops
            backward = (a - b) % self.num_stops
            return min(forward, backward)

        hold_idx = min(
            active_indices,
            key=lambda i: loop_distance(self.buses[i]["stop"], busiest_stop),
        )
        self.buses[hold_idx]["held"] = 1

    def _move_buses_and_board(self):
        total_picked_up = 0
        total_left_behind = 0

        for bus in self.buses:
            if bus["active"] == 0:
                continue

            # Move unless held
            if bus["held"] == 1:
                bus["held"] = 0
            else:
                bus["stop"] = self.next_stop(bus["stop"])

            stop = bus["stop"]

            # Board passengers
            waiting = int(self.queues[stop])
            available_space = self.bus_capacity - bus["occupancy"]

            boarded = min(waiting, available_space)
            left_behind = max(0, waiting - available_space)

            bus["occupancy"] += boarded
            self.queues[stop] -= boarded
            self.last_service[stop] = 0

            total_picked_up += boarded
            total_left_behind += left_behind

            # Simple drop-off rule:
            if stop == 0 or stop == 7:
                dropped = bus["occupancy"]  # All off at terminals
            else:
                dropped = int(
                    0.01 * bus["occupancy"]
                )  # some fraction of riders leave at each stop
            bus["occupancy"] -= dropped

        return total_picked_up, total_left_behind

    def next_stop(self, stop):
        return (stop + 1) % self.num_stops

    def is_westbound_stop(self, stop):
        return 0 <= stop <= 7

    def is_eastbound_stop(self, stop):
        return 8 <= stop <= 13

    def _active_bus_count(self):
        return sum(bus["active"] for bus in self.buses)

# %% [markdown]
# Part 3: Training Loop

# %%
# Register the environment so we can create it with gym.make()
gym.register(
    id="gymnasium_env/BusRouting-v0",
    entry_point=BusEnv,
    max_episode_steps=50000,  # Prevent infinite episodes
)

lr = [0.001, 0.0001, 0.000001]
envs = []

for l in lr:
    
    # Create the environment like any built-in environment
    env = gym.make("gymnasium_env/BusRouting-v0")
    env = gym.wrappers.RecordEpisodeStatistics(env, buffer_length=1000)
    env = Monitor(env)

    # Can adjust training hyperparameters of agent as needed
    model = PPO(
        policy="MlpPolicy",
        env=env,
        verbose=1,
        learning_rate=l,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.0
    )
    
    # Train the model
    model.learn(total_timesteps=100_000)
    
    envs.append(env)
    
    print(f"\nTraining of Agent complete!")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 960      |
# |    ep_rew_mean     | 4.38e+03 |
# | time/              |          |
# |    fps             | 1323     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 4.85e+03    |
# | time/                   |             |
# |    fps                  | 984         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014448925 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.000636   |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.56e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0299     |
# |    value_loss           | 4.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | 5.3e+03    |
# | time/                   |            |
# |    fps                  | 910        |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01469568 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.000119   |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.62e+03   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0238    |
# |    value_loss           | 6.66e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 5.65e+03    |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014905453 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.000379    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.43e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 8.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 5.92e+03    |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011768101 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.000607    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.91e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 9.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.09e+03    |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013413071 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 7.72e-05    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.89e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00839    |
# |    value_loss           | 9.4e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | 6.24e+03   |
# | time/                   |            |
# |    fps                  | 846        |
# |    iterations           | 7          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01275961 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 5.38e-05   |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.58e+03   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00948   |
# |    value_loss           | 8.6e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.4e+03     |
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011671527 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 3.64e-05    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.42e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 8.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.5e+03     |
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007861578 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 2.67e-05    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.13e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00786    |
# |    value_loss           | 7.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.58e+03    |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 10          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009390816 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 2.66e-05    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.21e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 7.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.65e+03    |
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011558404 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 1.44e-05    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.42e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 7.26e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 6.71e+03     |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 12           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0137673635 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 1.01e-05     |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.85e+03     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 6.98e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.75e+03    |
# | time/                   |             |
# |    fps                  | 827         |
# |    iterations           | 13          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014117954 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 3.34e-06    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.08e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 3.2e-05     |
# |    value_loss           | 6.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.79e+03    |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 14          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013514563 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 2.68e-06    |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.93e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00458    |
# |    value_loss           | 5.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.83e+03    |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 15          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018859748 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.976      |
# |    explained_variance   | 2.44e-06    |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.74e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00021     |
# |    value_loss           | 5.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.86e+03    |
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 16          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014257388 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 1.25e-06    |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.63e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00168     |
# |    value_loss           | 5.11e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | 6.88e+03   |
# | time/                   |            |
# |    fps                  | 822        |
# |    iterations           | 17         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01307777 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.888     |
# |    explained_variance   | 4.89e-06   |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.51e+03   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00444   |
# |    value_loss           | 4.73e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.91e+03    |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 18          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013887259 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 1.13e-06    |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 4.25e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.93e+03    |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 19          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.018024411 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 7.75e-07    |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.23e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 4.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.94e+03    |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 20          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015598906 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.742      |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.08e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000645    |
# |    value_loss           | 3.84e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | 6.96e+03   |
# | time/                   |            |
# |    fps                  | 819        |
# |    iterations           | 21         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02292997 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.718     |
# |    explained_variance   | 8.34e-07   |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.01e+03   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00581   |
# |    value_loss           | 3.58e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.98e+03    |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 22          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.022213366 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.14e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00825     |
# |    value_loss           | 3.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7e+03       |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 23          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.013672376 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.526      |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.001       |
# |    loss                 | 957         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000261   |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.02e+03    |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 24          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.019788777 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.435      |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.46e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.000842    |
# |    value_loss           | 3.88e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | 7.03e+03   |
# | time/                   |            |
# |    fps                  | 818        |
# |    iterations           | 25         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01343145 |
# |    clip_fraction        | 0.0722     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.37      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.29e+03   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00309   |
# |    value_loss           | 3.12e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.04e+03    |
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 26          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.031142704 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.322      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.38e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 3.05e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | 7.05e+03   |
# | time/                   |            |
# |    fps                  | 817        |
# |    iterations           | 27         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.02644085 |
# |    clip_fraction        | 0.0369     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.252     |
# |    explained_variance   | 3.58e-07   |
# |    learning_rate        | 0.001      |
# |    loss                 | 511        |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.000938   |
# |    value_loss           | 3.08e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.06e+03    |
# | time/                   |             |
# |    fps                  | 817         |
# |    iterations           | 28          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008430435 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | 0.00758     |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.04e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00327     |
# |    value_loss           | 3.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.07e+03    |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 29          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010489637 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | 0.0151      |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.11e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 3.2e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 30           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0066136867 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | 0.00381      |
# |    learning_rate        | 0.001        |
# |    loss                 | 755          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000499     |
# |    value_loss           | 3.16e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 31           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0024385233 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.282       |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.001        |
# |    loss                 | 538          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000253     |
# |    value_loss           | 4.43e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 32           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0066661537 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.001        |
# |    loss                 | 258          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.000926     |
# |    value_loss           | 3.13e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.08e+03    |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 33          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.013143081 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.278      |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.56e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0042      |
# |    value_loss           | 3.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.08e+03    |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 34          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008073002 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.311      |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.11e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.000201    |
# |    value_loss           | 3.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.08e+03    |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 35          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012482892 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.001       |
# |    loss                 | 526         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00484    |
# |    value_loss           | 3.18e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 960        |
# |    ep_rew_mean          | 7.08e+03   |
# | time/                   |            |
# |    fps                  | 814        |
# |    iterations           | 36         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01546101 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.347     |
# |    explained_variance   | 0.138      |
# |    learning_rate        | 0.001      |
# |    loss                 | 456        |
# |    n_updates            | 350        |
# |    policy_gradient_loss | 0.0137     |
# |    value_loss           | 3.38e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 37           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0060539767 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.318       |
# |    explained_variance   | 0.197        |
# |    learning_rate        | 0.001        |
# |    loss                 | 2.07e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 3.04e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.08e+03    |
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 38          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011837263 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.381      |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.001       |
# |    loss                 | 231         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.000498   |
# |    value_loss           | 3.41e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 39           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0053623887 |
# |    clip_fraction        | 0.0581       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.377       |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.001        |
# |    loss                 | 999          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 4.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 814          |
# |    iterations           | 40           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0051241084 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.287       |
# |    explained_variance   | 0.331        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.14e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 2.65e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 41           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0033401784 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.302       |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.001        |
# |    loss                 | 237          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000393    |
# |    value_loss           | 2.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 42           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0039522294 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | 0.468        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.31e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00322      |
# |    value_loss           | 2.44e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.08e+03    |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 43          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007632291 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.327      |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.001       |
# |    loss                 | 358         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00843     |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 44           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0016858744 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.327       |
# |    explained_variance   | 0.619        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.29e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000884    |
# |    value_loss           | 2.06e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.08e+03    |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 45          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.006299898 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.317      |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.001       |
# |    loss                 | 641         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00247    |
# |    value_loss           | 3.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.08e+03    |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 46          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005059243 |
# |    clip_fraction        | 0.0248      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.3        |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.001       |
# |    loss                 | 537         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 4.03e-06    |
# |    value_loss           | 3.64e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.08e+03     |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 47           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0031669172 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.291       |
# |    explained_variance   | 0.541        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.03e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000903    |
# |    value_loss           | 2.87e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 7.14e+03     |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 48           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0014940316 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | 0.421        |
# |    learning_rate        | 0.001        |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 3.1e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 7.17e+03    |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 49          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004576953 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.241      |
# |    explained_variance   | 0.52        |
# |    learning_rate        | 0.001       |
# |    loss                 | 440         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 2.97e+03    |
# -----------------------------------------
#
# Training of Agent complete!
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 960      |
# |    ep_rew_mean     | 3.92e+03 |
# | time/              |          |
# |    fps             | 1467     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 4.58e+03    |
# | time/                   |             |
# |    fps                  | 1041        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014544104 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000421    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 4.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 5.19e+03    |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010620481 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.00744    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.6e+03     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 8.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 5.53e+03    |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011914115 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.00452     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.97e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 1.22e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 5.81e+03    |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012689414 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.00658     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.2e+03     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00995    |
# |    value_loss           | 1.3e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 6.05e+03     |
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 6            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0055627017 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.00466      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.95e+03     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00581     |
# |    value_loss           | 1.42e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 6.2e+03     |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 7           |
# ...
# |    approx_kl            | 4.124915e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00558      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.75e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000255    |
# |    value_loss           | 9.47e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.64e+03     |
# | time/                   |              |
# |    fps                  | 666          |
# |    iterations           | 33           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 8.849864e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 9.38e-05     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.07e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000443    |
# |    value_loss           | 7.51e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.67e+03     |
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 34           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 9.094394e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00196      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.24e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000449    |
# |    value_loss           | 8.08e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | 4.67e+03      |
# | time/                   |               |
# |    fps                  | 539           |
# |    iterations           | 35            |
# |    time_elapsed         | 132           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 4.9466908e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.00617       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.34e+03      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00029      |
# |    value_loss           | 9.31e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.69e+03     |
# | time/                   |              |
# |    fps                  | 526          |
# |    iterations           | 36           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 8.251809e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000846     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.31e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000407    |
# |    value_loss           | 7.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.69e+03     |
# | time/                   |              |
# |    fps                  | 522          |
# |    iterations           | 37           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 3.952271e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00386      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.22e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000223    |
# |    value_loss           | 8.78e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.7e+03      |
# | time/                   |              |
# |    fps                  | 520          |
# |    iterations           | 38           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 8.913805e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00127      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 3.5e+03      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000416    |
# |    value_loss           | 7.5e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.71e+03     |
# | time/                   |              |
# |    fps                  | 462          |
# |    iterations           | 39           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 5.966809e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00511      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 3.79e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000338    |
# |    value_loss           | 8.07e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | 4.73e+03      |
# | time/                   |               |
# |    fps                  | 418           |
# |    iterations           | 40            |
# |    time_elapsed         | 195           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 6.9162925e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.00622       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.23e+03      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000381     |
# |    value_loss           | 8.81e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.75e+03     |
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 41           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 6.371818e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000195     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.36e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000298    |
# |    value_loss           | 9.25e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | 4.77e+03      |
# | time/                   |               |
# |    fps                  | 354           |
# |    iterations           | 42            |
# |    time_elapsed         | 242           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 5.5936107e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0129        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.6e+03       |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000307     |
# |    value_loss           | 9.53e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.78e+03     |
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 43           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 6.055605e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000525     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 5.4e+03      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000302    |
# |    value_loss           | 1.01e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.78e+03     |
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 44           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 6.180664e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00573      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.21e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000299    |
# |    value_loss           | 8.22e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 4.8e+03      |
# | time/                   |              |
# |    fps                  | 336          |
# |    iterations           | 45           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 8.374511e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00403      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.37e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000382    |
# |    value_loss           | 8.34e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | 4.82e+03      |
# | time/                   |               |
# |    fps                  | 336           |
# |    iterations           | 46            |
# |    time_elapsed         | 279           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 8.2721235e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00336       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.18e+03      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000392     |
# |    value_loss           | 8.68e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | 4.83e+03      |
# | time/                   |               |
# |    fps                  | 322           |
# |    iterations           | 47            |
# |    time_elapsed         | 298           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 7.5456337e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00818       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 4.77e+03      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.0004       |
# |    value_loss           | 9.12e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | 4.86e+03      |
# | time/                   |               |
# |    fps                  | 315           |
# |    iterations           | 48            |
# |    time_elapsed         | 311           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 5.3104013e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00684       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 5.37e+03      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000303     |
# |    value_loss           | 1.01e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 960           |
# |    ep_rew_mean          | 4.9e+03       |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 49            |
# |    time_elapsed         | 333           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 4.2859174e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.37         |
# |    explained_variance   | 0.00968       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 5.17e+03      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000218     |
# |    value_loss           | 9.82e+03      |
# -------------------------------------------
#
# Training of Agent complete!

# %%
def _get_returns_from_env(env):
    if hasattr(env, "return_queue"):
        return np.array(env.return_queue)

    inner_env = getattr(env, "env", None)
    if inner_env is not None and hasattr(inner_env, "return_queue"):
        return np.array(inner_env.return_queue)

    if hasattr(env, "get_episode_rewards"):
        return np.array(env.get_episode_rewards())

    raise AttributeError(
        "Environment does not expose episode returns. "
        "Wrap the env with RecordEpisodeStatistics or Monitor."
    )


def visualize_learning_curves(envs, smoothing=10, labels=None):
    fig, ax = plt.subplots(1, 1, figsize=(20, 8))

    if labels is None:
        labels = [f"Run {i}" for i in range(len(envs))]

    for env, label in zip(envs, labels):
        returns = _get_returns_from_env(env)
        returns_smoothed = np.convolve(
            returns, np.ones(smoothing) / smoothing, mode='valid'
        )

        ax.plot(returns_smoothed, label=label)

    ax.set_title("Episode Returns", fontsize=20)
    ax.set_xlabel("Episode", fontsize=20)
    ax.set_ylabel("Return", fontsize=20)
    ax.legend()

    plt.tight_layout()
    plt.show()
    
visualize_learning_curves(envs=envs, smoothing=10, labels=[0.001, 0.0001, 0.000001])
